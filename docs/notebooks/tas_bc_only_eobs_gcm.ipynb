# %% [markdown]
# # BC-only tas workflow with E-OBS and GCM
#
# This notebook shows how to stop after bias correction when you want to assess BC itself without training a downscaling model.

# %%
WORKFLOW_RUNNER = "bin/production/run_obs_workflow.py"
EXP = "exp5"

# %%
# !python {WORKFLOW_RUNNER} --exp {EXP} --steps phase1,stats,bc_dataset,bc_apply --simu gcm --if-exists skip
# !python bin/evaluation/validate_bc_outputs.py --exp {EXP} --simu gcm --var tas

# %% [markdown]
# ## Validation focus
#
# - corrected NetCDF naming and date windows
# - packaged BC samples under the experiment-specific directory
# - BC validation metrics and plots before any ML stage
