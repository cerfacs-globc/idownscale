# %% [markdown]
# # Perfect-model BC+CDDPM workflow with RCM input
#
# This notebook documents the perfect-model workflow where bias-corrected coarse inputs are passed to a diffusion model, then evaluated against the dedicated perfect-model evaluation dataset.

# %%
EXP = "perfect_model_rcm"
TEST_NAME = "cddpm_bcml"

# %%
# !python bin/training/train.py --exp {EXP} --test-name {TEST_NAME} --model cddpm --output-norm --batch-size 16 --max-epoch 30
# !python bin/training/predict_loop.py --exp {EXP} --test-name {TEST_NAME} --simu-test rcm_bc --num-samples 8

# %% [markdown]
# ## Validation focus
#
# - verify the prediction sample tree is the perfect-model evaluation dataset, not the training dataset
# - verify the checkpoint still points to the run-local normalization statistics
# - inspect prediction provenance for `idownscale_diffusion_num_samples`, perfect-model source fields, and resolved path inventory
